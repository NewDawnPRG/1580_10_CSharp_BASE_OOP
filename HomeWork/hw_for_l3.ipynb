# %% [markdown]
# ---
#
# ### 1. **Цветная радуга**
# Напишите программу, которая поочерёдно:
# - Очищает экран.
# - Выводит строку «Красный» красным текстом.
# - Ждёт нажатия клавиши.
# - Очищает экран, выводит «Зелёный» зелёным текстом.
# - Ждёт нажатия.
# - Очищает, выводит «Синий» синим текстом.
# - Сбрасывает цвета.
#
# ---
#
# ### 2. **Звуковой семафор**
# Программа:
# - Выводит: «Сигнал 1» и подаёт звук 400 Гц, 300 мс.
# - Ждёт нажатия клавиши.
# - Выводит: «Сигнал 2» и подаёт звук 800 Гц, 200 мс.
# - Ждёт нажатия.
# - Выводит: «Сигнал 3» и подаёт звук 600 Гц, 400 мс.
#
# ---
#
# ### 3. **Мигающий текст**
# Программа:
# - Устанавливает жёлтый текст на чёрном фоне.
# - Выводит: «Внимание!»
# - Ждёт нажатия клавиши.
# - Меняет фон на красный (текст остаётся жёлтым).
# - Ждёт ещё одного нажатия.
# - Сбрасывает цвета.
#
# ---
#
# ### 4. **Консольный таймер**
# Программа:
# - Очищает экран.
# - Выводит: «3» (белым).
# - Ждёт нажатия.
# - Очищает, выводит: «2» (жёлтым).
# - Ждёт нажатия.
# - Очищает, выводит: «1» (красным).
# - Подает звуковой сигнал.
# - Выводит: «Старт!»
#
# ---
#
# ### 5. **Цветной эхо-ввод (реакция на клавишу)**
# Программа:
# - Просит нажать любую клавишу.
# - После нажатия (`ReadKey`) **немедленно**:
#   - Меняет цвет текста на случайный (выберите один, например, зелёный),
#   - Выводит: «Вы нажали клавишу!»
#   - Подает короткий звук.
#
# ---
#
# ### 6. **Фон меняет цвет**
# Программа:
# - Устанавливает белый текст.
# - Устанавливает синий фон и выводит: «Фон: синий».
# - Ждёт нажатия.
# - Меняет фон на зелёный, выводит: «Фон: зелёный».
# - Ждёт нажатия.
# - Меняет фон на красный, выводит: «Фон: красный».
# - Сбрасывает цвета.
#
# ---
#
# ### 7. **Звук + цвет = сигнал**
# Программа:
# - Устанавливает красный текст на белом фоне.
# - Выводит: «Тревога!»
# - Подает звук 500 Гц, 500 мс.
# - Ждёт нажатия.
# - Сбрасывает цвета и выводит: «Тревога завершена.»
#
# ---
#
# ### 8. **Построчный ввод с очисткой**
# Программа:
# - Выводит: «Нажмите Enter, чтобы очистить экран.»
# - Ждёт `ReadLine()` (то есть Enter).
# - Очищает экран.
# - Выводит: «Экран очищен!» зелёным цветом.
# - Подает звук 700 Гц, 200 мс..
#
# ---
#
# ### 9. **Двойной звук по нажатию**
# Программа:
# - Выводит: «Нажмите любую клавишу для проигрывания мелодии.»
# - Ждёт `ReadKey()`.
# - Проигрывает два звука подряд: 600 Гц (200 мс), затем 900 Гц (200 мс).
# - Выводит: «Мелодия завершена.» синим цветом.
#
# ---
#
# ### 10. **Цветной каскад**
# Программа:
# - Очищает экран.
# - Выводит «Шаг 1» белым текстом на чёрном фоне.
# - Ждёт нажатия.
# - Очищает, выводит «Шаг 2» чёрным текстом на белом фоне.
# - Ждёт нажатия.
# - Очищает, выводит «Шаг 3» жёлтым текстом на красном фоне.
# - Ждёт нажатия.
# - Сбрасывает цвета и выводит: «Готово!»
#
# ---

# %%
import random

variant = 1  # Замените на ваш вариант
random.seed(variant+(36*23))
numbers = random.sample(range(1, 11), 2)
print("Ваши числа:", numbers)
# Out:
# Ваши числа: [4, 5]
