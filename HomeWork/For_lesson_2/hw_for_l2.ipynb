# %% [markdown]
# Варианты задач:
#
# 1. Вариант 1: Напишите алгоритм поиска минимального числа в списке.
# 2. Вариант 2: Напишите алгоритм проверки, является ли число простым.
# 3. Вариант 3: Напишите алгоритм вычисления факториала числа.
# 4. Вариант 4: Напишите алгоритм переворота строки.
# 5. Вариант 5: Напишите алгоритм подсчета количества чётных чисел в списке.
# 6. Вариант 6: Напишите алгоритм поиска суммы элементов списка.
# 7. Вариант 7: Напишите алгоритм проверки, является ли строка палиндромом.
# 8. Вариант 8: Напишите алгоритм преобразования числа в двоичную систему.
# 9. Вариант 9: Напишите алгоритм проверки числа n на работу гипотезы Коллатца
# 10. Вариант 10: Напишите алгоритм вычисления чисел Фибоначчи до заданного n.
# 11. Вариант 11: Напишите алгоритм нахождения НОД двух чисел.
# 12. Вариант 12: Напишите алгоритм возведения числа в степень

# %%
import random

variant = 1  # Замените на ваш вариант
random.seed(variant)
numbers = random.sample(range(1, 13), 3)
print("Ваши числа:", numbers)
# Out:
# Ваши числа: [3, 10, 2]
