# %% [markdown]
# ### При выполнении заданий рекомендуется писать алгоритм, и не пихать все действия в одну строку.
#
# 1. Даны два целых числа (от -30000 до 30000). Вывести максимальное число. Если они равны - вывести любое.
# 2. Даны три различных вещественных числа (от -30000 до 30000). Вывести среднее из них.
# 3. Дано трехзначное натуральное число. Удвоить это число если в его записи есть хотя бы одна единица и возвести в квадрат в противном случае.
# 4. Дано натуральное двузначное число. Составить программу определения, является ли сумма его цифр двузначным числом. Если нет, то через сколько чисел встретиться первое двузначное число, удовлетворяющее этому условию.
# 5. По заданным координатам точки определить номер четверти на координатной плоскости, где она находится.
#
# > Формат ввода:
#
# На первой строке - координата X, на второй строке - Y. Обе координаты - целые числа в диапазоне от -10000 до 10000.
#
# > Формат вывода:
#
# Целое число - номер черверти, где лежит точка. Если точка лежит на оси координат между четвертями, то вывести номера двух четвертей на одной строке без пробела (вначале меньший номер, потом больший), например "14" для точки с координатами (5,0) т.к. она лежит на оси ОХ между 1-й и 4-й четвертями. Если точка лежит в начале координат - вывести 0.
#
# 6. Дано натуральное двузначное число. Составить программу определения, является ли сумма его цифр двузначным числом. Если нет, то через сколько чисел встретиться первое двузначное число, удовлетворяющее этому условию.
#
# ## По вариантам
# 1. Напишите программу, которая:
#
# - Запрашивает у пользователя текущую температуру на улице сегодня, и прогноз на завтра
#
# - Выдает рекомендации (для двух дней):
#
# - - Если ниже 0°C: "Оденьтесь очень тепло, на улице мороз!"
#
# - - Если от 0°C до 15°C: "Наденьте куртку, прохладно"
#
# - - Если от 16°C до 25°C: "Идеальная погода, можно в футболке"
#
# - - Если выше 25°C: "Жарко, наденьте что-то легкое"
# ---
# 2. Напишите программу, которая:
#
# - Запрашивает у пользователя номер дня недели (1-7)
#
# - Используя оператор switch, выводит название дня на английском
#
# - Для неверных номеров выводит "Неверный номер дня"
# ---
# 3. Магазин предоставляет скидки:
#
# - При покупке от 1000 руб. - скидка 3%
#
# - При покупке от 5000 руб. - скидка 5%
#
# - При покупке от 10000 руб. - скидка 10%
#
# - Постоянным клиентам (логическая переменная) - дополнительно +2% к любой скидке
#
# Напишите программу, которая:
#
# - Запрашивает сумму покупки
#
# - Спрашивает, является ли покупатель постоянным клиентом
#
# - Рассчитывает и выводит итоговую сумму к оплате
#
# ---
#
# 4. Напишите программу для автоматизации выставления итоговой оценки студенту:
#
# Входные данные:
#
# - Количество баллов за экзамен (0-100)
#
# - Процент посещаемости занятий (0-100%)
#
# Правила:
#
# - Если посещаемость ниже 75% - оценка снижается на 1 балл
#
# - Если посещаемость ниже 50% - оценка снижается на 2 балла
#
# Шкала оценок:
#
# - 90-100 баллов: "Отлично"
#
# - 70-89 баллов: "Хорошо"
#
# - 50-69 баллов: "Удовлетворительно"
#
# - Меньше 50: "Неудовлетворительно"
#
# Программа должна выводить итоговую оценку с учетом посещаемости.

# %%
import random

variant = 1  # Замените на ваш вариант
random.seed(variant + (34573)//55+346)

first = random.randint(1, 2)
second = random.randint(3, 4)

numbers = [first, second]
print("Ваши числа:", numbers)
# Out:
# Ваши числа: [2, 3]
