# %% [markdown]
# ### При выполнении заданий рекомендуется писать алгоритм, и не пихать все действия в одну строку.
#
# > Список задач в качестве ДЗ с 3 на 4 занятие
#
# ### **Блок 1. Обязательный**
# 1. Дано вещественное число. Вывести отдельно его целую и дробную часть.
# 2. С клавиатуры вводится целое число k
# (1 ≤ k ≤ 180) . Определить k-ю цифру в последовательности двузначных чисел, выписанных подряд (1011121314............979899).
# Оператор if не использовать
# 3. Дано целое трехзначное число N, значение которого вводится с клавиатуры. Написать программу, которая выводит на экран true , если сумма каких-либо двух цифр числа N равна третьей цифре, false в противном случае.
#
#
# > *Второе задание лучше делать после 3 блока*, *Третье после 4*,  а так же необходимо написать алгоритм
# ### **Блок 2. По вариантам**
# 1. Вводится длина окружности. Определить площадь круга, ограниченного этой окружностью.
# 2. Вводятся координаты двух точек на плоскости (x1,y1,x2,y2). Найти расстояние между этими точками.
# 3. Вводятся гипотенуза и катет треугольника. Найти периметр и площадь треугольника.
# 4. Два автомобиля едут навстречу друг другу с постоянными скоростями V1 и V2 км/час. Определить, через какое время автомобили встретятся, если расстояние между ними было S км.
# 5. Вводится радиус окружности, описанной вокруг квадрата. Определить периметр и площадь этого квадрата.
# 6. Вводится сторона квадрата. В квадрат вписана окружность. Найти ее радиус и длину.
#
# ### **Блок 3. По варианту**
# 1. В числе X записано некоторое целое положительное число. Записать в число Y значение 10, если X чётное и записать -10, если X нечётное. Оператор if использовать не разрешается.
# 2. В числе X записано некоторое число. Записать в число Y значение 10, если X нечётное и записать 70, если X чётное. Оператор if использовать не разрешается.
#
# ### **Блок 4. По вариантам**
# 1. Даны два числа X и Y, значения которых вводятся с клавиатуры. Написать программу, которая выводит на экран true, если выполняются условия X>2 и Y>3, false в противном случае.
# 2. Даны два числа X и Y, значения которых вводятся с клавиатуры. Написать программу, которая выводит на экран true , если только одно из чисел X и Y нечетное, false в противном случае.
# 3. Дано целое число A, значение которого вводится с клавиатуры. Написать программу, которая выводит на экран true , если A не кратно трем и оканчивается нулем, false в противном случае.

# %%
import random

variant = 1  # Замените на ваш вариант
random.seed(variant + ((2**3 + 3**2)*11+7))

first = random.randint(1, 6)
second = random.randint(1, 2)
third = random.randint(1, 3)

numbers = [first, second, third]
print("Ваши числа:", numbers)
# Out:
# Ваши числа: [5, 2, 1]
