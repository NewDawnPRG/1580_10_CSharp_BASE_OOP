# %% [markdown]
# ### **1. Написать алгоритм**
#
# **Задача 1.1**
# Составьте алгоритм для программы, которая запрашивает у пользователя коэффициенты a, b, c квадратного уравнения ax² + bx + c = 0 и выводит его корни (с учётом комплексных решений).
#
# **Задача 1.2**
# Составьте алгоритм для программы, которая запрашивает у пользователя количество часов и переводит его в минуты и секунды.
#
# **Задача 1.3**
# Составьте алгоритм для программы, которая запрашивает у пользователя число N и выводит все простые числа в диапазоне от 2 до N.
#
# **Задача 1.4**
# Составьте алгоритм для программы, которая запрашивает у пользователя пароль. Если пароль правильный, выводит "Доступ разрешён", иначе — "Доступ запрещён".
#
# **Задача 1.5**
# Составьте алгоритм для программы, которая запрашивает у пользователя число и проверяет, является ли оно совершенным (сумма делителей равна самому числу).
#
# **Задача 1.6**
# Составьте алгоритм для программы, которая запрашивает у пользователя число N, а затем выводит сумму всех чисел от 1 до N.
#
# **Задача 1.7**
# Составьте алгоритм для программы, которая запрашивает у пользователя 5 чисел и выводит наибольшее из них.
#
# **Задача 1.8**
# Составьте алгоритм для программы, которая выводит таблицу умножения на 5 (от 1 до 10).
#
# **Задача 1.9**
# Составьте алгоритм для программы, которая генерирует случайное число от 1 до 100 и дает пользователю 7 попыток чтобы угадать его, сообщая "больше" или "меньше" после каждой попытки.
#
# **Задача 1.10**
# Составьте алгоритм для программы, которая запрашивает у пользователя число и проверяет, является ли оно палиндромом.
#
# ---
#
# ### **2. Решить задачу, связанную с типами данных и консолью**
#
# **Задача 2.1**
# Напишите программу, которая запрашивает у пользователя длину ребра куба и выводит его объем и площадь полной поверхности.
#
# **Задача 2.2**
# Напишите программу, которая запрашивает радиус круга и выводит его площадь. Используйте константу `Math.PI`.
#
# **Задача 2.3**
# Напишите программу, которая запрашивает у пользователя три числа (int) и выводит их среднее арифметическое.
#
# **Задача 2.4**
# Напишите программу, которая запрашивает у пользователя два катета прямоугольного треугольника и выводит длину гипотенузы.
#
# **Задача 2.5**
# Напишите программу, которая запрашивает у пользователя сумму в рублях (int) и выводит эквивалент в долларах (курс: 1 доллар = 92.5 рубля).
#
# **Задача 2.6**
# Напишите программу, которая запрашивает у пользователя два числа (double) и выводит результат деления их суммы на их разность. Гарантируется, что числа не равны.
#
# **Задача 2.7**
# Напишите программу, которая запрашивает у пользователя количество градусов в угле и переводит его в радианы.
#
# **Задача 2.8**
# Напишите программу, которая запрашивает у пользователя длину и ширину прямоугольника (double) и выводит его периметр и площадь.
#
# **Задача 2.9**
# Напишите программу, которая запрашивает у пользователя время в секундах (int) и переводит его в часы, минуты и секунды (например, 3665 секунд = 1 час 1 минута 5 секунд).
#
# **Задача 2.10**
# Напишите программу, которая запрашивает у пользователя два числа (int) и выводит результат целочисленного деления и остаток от деления.
#
# ---
#
# ### **3. Решить задачу, связанную со всеми темами**
#
# **Задача 3.1**
# Напишите программу, которая запрашивает у пользователя числа до тех пор, пока не будет введён 0. Затем программа выводит сумму всех введённых положительных чисел.
#
# **Задача 3.2**
# Напишите программу, в которой задано случайное число от 1 до 100 и предлагает пользователю угадать его. Программа должна давать подсказки "Больше" или "Меньше", пока число не будет угадано.
#
# **Задача 3.3**
# Напишите программу, которая запрашивает у пользователя число N, а затем выводит все простые числа в диапазоне от 2 до N.
#
# **Задача 3.4**
# Напишите программу, которая запрашивает у пользователя число и проверяет, является ли оно палиндромом (читается одинаково слева направо и справа налево).
#
# **Задача 3.5**
# Напишите программу, которая выводит на экран все трёхзначные числа, сумма цифр которых равна 15.
#
# **Задача 3.6**
# Напишите программу, которая запрашивает у пользователя число N и выводит все числа от 1 до N, которые делятся и на 3, и на 5 одновременно.
#
# **Задача 3.7**
# Напишите программу, которая запрашивает у пользователя число и выводит его факториал. Используйте цикл.
#
# **Задача 3.8**
# Напишите программу, которая запрашивает у пользователя число и выводит таблицу умножения для этого числа от 1 до 10.
#
# **Задача 3.9**
# Напишите программу, которая запрашивает у пользователя пароль. Если пароль неверный, программа должна запрашивать его снова, но не более 3 раз. После 3 неудачных попыток вывести "Доступ заблокирован". Предполагается, что пароль состоит только из цифр.
#
# **Задача 3.10**
# Напишите программу, которая реализует игру "Быки и коровы". Компьютер загадывает 4-значное число без повторяющихся цифр. Пользователь пытается угадать, получая подсказки: "быки" (правильные цифры на своих местах) и "коровы" (правильные цифры не на своих местах).
#
# ---

# %%
import random

variant = 1  # Замените на ваш вариант

random.seed(variant + 34564)
first = random.randint(1, 10)

random.seed(variant + 3)

second = random.randint(1, 10)
third = random.randint(1, 10)

numbers = [first, second, third]
print("Ваши числа:", numbers)
# Out:
# Ваши числа: [8, 4, 5]
